# %% [markdown]
# ## Notebook 4A: Seatwork
#
# This seatwork should be submitted <b>by LT</b>.
#
# LT Number:
#
# Names:

# %% [markdown]
# #### Q1.
#
# Given the following:
#
# \begin{align*}
#     \begin{bmatrix}
#     1 & 3 & 3 & -2\\
#     2 & 2 & 1 & 1\\
#     4 & 2 & -1 & 5\\
#     -3 & 2 & -5 & 5
#     \end{bmatrix} \begin{bmatrix}
#     x_1\\
#     x_2\\
#     x_3\\
#     x_4
#     \end{bmatrix} =
#     \begin{bmatrix}
#     1\\
#     2\\
#     3\\
#     4
#     \end{bmatrix}
# \end{align*}

# %% [markdown]
# Do the following:
#
# 1) Calculate $\text{det}(A)$.

# %% [markdown]
# $
# \begin{align}
# \text{det}(A) &= \begin{vmatrix}
#                  1 & 3 & 3 & -2\\
#                  2 & 2 & 1 & 1\\
#                  4 & 2 & -1 & 5\\
#                  -3 & 2 & -5 & 5
#                  \end{vmatrix}\\
#    &= (1)\begin{vmatrix}
#          2 & 1 & 1\\
#          2 & -1 & 5\\
#          2 & -5 & 5
#          \end{vmatrix}
#    -  (3)\begin{vmatrix}
#          2 & 1 & 1\\
#          4 & -1 & 5\\
#          -3 & -5 & 5
#          \end{vmatrix}
#     + (3)\begin{vmatrix}
#          2 & 1 & 1\\
#          4 & 2 & 5\\
#          -3 & 2 & 5
#          \end{vmatrix}
#     - (-2)\begin{vmatrix}
#           2 & 1 & 1\\
#           4 & 2 & -1\\
#           -3 & 2 & -5
#           \end{vmatrix}\\
#    &= 1\left[+ (2)\begin{vmatrix}
#                   -1 & 5\\
#                   -5 & 5
#                   \end{vmatrix}
#              - (1)\begin{vmatrix}
#                   2 & 5\\
#                   2 & 5
#                   \end{vmatrix}
#              + (1)\begin{vmatrix}
#                   2 & -1\\
#                   2 & -5
#                   \end{vmatrix}\right]\\
#       &\quad -3\left[+ (2)\begin{vmatrix}
#                           -1 & 5\\
#                           -5 & 5
#                           \end{vmatrix}
#                      - (1)\begin{vmatrix}
#                           4 & 5\\
#                           -3 & 5
#                           \end{vmatrix}
#                      + (1)\begin{vmatrix}
#                           4 & -1\\
#                           -3 & -5
#                           \end{vmatrix}\right]\\
#       &\quad +3\left[+ (2)\begin{vmatrix}
#                           2 & 5\\
#                           2 & 5
#                           \end{vmatrix}
#                      - (2)\begin{vmatrix}
#                           4 & 5\\
#                           -3 & 5
#                           \end{vmatrix}
#                      + (1)\begin{vmatrix}
#                           4 & 2\\
#                           -3 & 2
#                           \end{vmatrix}\right]\\
#       &\quad +2\left[+ (2)\begin{vmatrix}
#                           2 & -1\\
#                           2 & -5
#                           \end{vmatrix}
#                      - (2)\begin{vmatrix}
#                           4 & -1\\
#                           -3 & -5
#                           \end{vmatrix}
#                      + (1)\begin{vmatrix}
#                           4 & 2\\
#                           -3 & 2
#                           \end{vmatrix}\right]\\
#   &= 1\left[2(-5+25) - 1(10-10) + 1(-10+2)\right]\\
#      &\quad -3\left[2(-5+25) - 1(20+15) + 1(-20-3)\right]\\
#      &\quad +3\left[2(10-10) - 2(20+15) + 1(8+6)\right]\\
#      &\quad +2\left[2(-10+2) - 2(-20-3) + 1(8+6)\right]\\
#   &= 1(40-8) -3(40-35-23) +3(-70+14) +2(-16+46+14)\\
#   &= 32+54-168+88\\
#   &= \boxed{6}
# \end{align}
# $

# %% [markdown]
# 2) Solve for $x$ using Cramer's Rule.

# %% [markdown]
# $x_i = \frac{\text{det}(A_i)}{\text{det}(A)}$ where $A_i$ is the resulting matrix when the $i$th column is replaced by $b$.
#
# **Solving for $x_1$ = $\frac{\text{det}(A_1)}{\text{det}(A)}$**:
#
# $
# \begin{align}
# \text{det}(A_1) &= \begin{vmatrix}
#                    1 & 3 & 3 & -2\\
#                    2 & 2 & 1 & 1\\
#                    3 & 2 & -1 & 5\\
#                    4 & 2 & -5 & 5
#                    \end{vmatrix}\\
#    &= (1)\begin{vmatrix}
#          2 & 1 & 1\\
#          2 & -1 & 5\\
#          2 & -5 & 5
#          \end{vmatrix}
#    -  (3)\begin{vmatrix}
#          2 & 1 & 1\\
#          3 & -1 & 5\\
#          4 & -5 & 5
#          \end{vmatrix}
#    +  (3)\begin{vmatrix}
#          2 & 1 & 1\\
#          3 & 2 & 5\\
#          4 & 2 & 5
#          \end{vmatrix}
#    - (-2)\begin{vmatrix}
#          2 & 1 & 1\\
#          3 & 2 & -1\\
#          4 & 2 & -5
#          \end{vmatrix}\\
#    &= 1\left[+ (2)\begin{vmatrix}
#                   -1 & 5\\
#                   -5 & 5
#                   \end{vmatrix}
#              - (1)\begin{vmatrix}
#                   2 & 5\\
#                   2 & 5
#                   \end{vmatrix}
#              + (1)\begin{vmatrix}
#                   2 & -1\\
#                   2 & -5
#                   \end{vmatrix}\right]\\
#       &\quad -3\left[  (2)\begin{vmatrix}
#                            -1 & 5\\
#                            -5 & 5
#                            \end{vmatrix}
#                      - (1)\begin{vmatrix}
#                           3 & 5\\
#                           4 & 5
#                           \end{vmatrix}
#                      + (1)\begin{vmatrix}
#                           3 & -1\\
#                           4 & -5
#                           \end{vmatrix}\right]\\
#       &\quad +3\left[  (2)\begin{vmatrix}
#                           2 & 5\\
#                           2 & 5
#                           \end{vmatrix}
#                      - (2)\begin{vmatrix}
#                           3 & 5\\
#                           4 & 5
#                           \end{vmatrix}
#                      + (1)\begin{vmatrix}
#                           3 & 2\\
#                           4 & 2
#                           \end{vmatrix}\right]\\
#       &\quad +2\left[  (2)\begin{vmatrix}
#                            2 & -1\\
#                            2 & -5
#                            \end{vmatrix}
#                      - (2)\begin{vmatrix}
#                           3 & -1\\
#                           4 & -5
#                           \end{vmatrix}
#                      + (1)\begin{vmatrix}
#                           3 & 2\\
#                           4 & 2
#                           \end{vmatrix}\right]\\
#   &= 1\left[2(-5+25) - 1(10-10) + 1(-10+2)\right]\\
#      &\quad -3\left[2(-5+25) - 1(15-20) + 1(-15+4)\right]\\
#      &\quad +3\left[2(10-10) - 2(15-20) + 1(6-8)\right]\\
#      &\quad +2\left[2(-10+2) - 2(-15+4) + 1(6-8)\right]\\
#   &= 1(40-8) -3(40+5-11) +3(10-2) +2(-16+22-2)\\
#   &= 32+102-24+8\\
#   &= \boxed{-38}
# \end{align}
# $
#
# $\Longrightarrow$ $x_1 = \frac{-38}{6} = \boxed{\frac{-19}{3}}$

# %% [markdown]
# **Solving for $x_2$ = $\frac{\text{det}(A_2)}{\text{det}(A)}$**:

# %% [markdown]
# **Solving for $x_3$ = $\frac{\text{det}(A_3)}{\text{det}(A)}$**:

# %% [markdown]
# **Solving for $x_4$ = $\frac{\text{det}(A_4)}{\text{det}(A)}$**:

# %% [markdown]
# #### Q2.
#
# Given the following:
#
# \begin{align*}
#     \begin{bmatrix}
#     1 & 3 & 5\\
#     2 & 2 & 2\\
#     2 & 3 & -1
#     \end{bmatrix} \begin{bmatrix}
#     x_1\\
#     x_2\\
#     x_3
#     \end{bmatrix} =
#     \begin{bmatrix}
#     1\\
#     2\\
#     3
#     \end{bmatrix}
# \end{align*}

# %% [markdown]
# Do the following:
#
# 1) Calculate $A^{-1}$ using the method of cofactors.

# %% [markdown]
# $A^{-1} = \frac{\text{adj}(A)}{\text{det}(A)}$ where $\text{adj}(A) = C^T$.
#
# **Solving for $\text{det}(A)$:**
#
# $
# \begin{align}
# \text{det}(A) &= \begin{vmatrix}
#                    1 & 3 & 5\\
#                    2 & 2 & 2\\
#                    2 & 3 & -1
#                    \end{vmatrix}\\
#               &= + (1)\begin{vmatrix}
#                       2 & 2\\
#                       3 & -1
#                       \end{vmatrix}
#                  - (3)\begin{vmatrix}
#                       2 & 2\\
#                       2 & -1
#                       \end{vmatrix}
#                  + (5)\begin{vmatrix}
#                       2 & 2\\
#                       2 & 3
#                       \end{vmatrix}\\
#               &= 1(-2-6) -3(-2-4) + 5(6-4)\\
#               &= -8+18+10\\
#               &= \boxed{20}
# \end{align}
# $

# %% [markdown]
# **Solving for $C^T$:**
#
# $C = \begin{bmatrix}
#      M_{11} & M_{12} & M_{13}\\
#      M_{21} & M_{22} & M_{23}\\
#      M_{31} & M_{32} & M_{33}
#      \end{bmatrix}$
#
# $M_{11}= \begin{bmatrix}
#          2 & 2\\
#          3 & -1
#          \end{bmatrix}
# \quad
# M_{12}= \begin{bmatrix}
#          2 & 2\\
#          2 & -1
#          \end{bmatrix}
# \quad
# M_{13}= \begin{bmatrix}
#          2 & 2\\
#          2 & 3
#          \end{bmatrix}\\
# M_{21}= \begin{bmatrix}
#          3 & 5\\
#          3 & -1
#          \end{bmatrix}
# \quad
# M_{22}= \begin{bmatrix}
#          1 & 5\\
#          2 & -1
#          \end{bmatrix}
# \quad
# M_{23}= \begin{bmatrix}
#          1 & 3\\
#          2 & 3
#          \end{bmatrix}\\
# M_{31}= \begin{bmatrix}
#          3 & 5\\
#          2 & 2
#          \end{bmatrix}
# \quad
# M_{32}= \begin{bmatrix}
#          1 & 5\\
#          2 & 2
#          \end{bmatrix}
# \quad
# M_{33}= \begin{bmatrix}
#          1 & 3\\
#          2 & 2
#          \end{bmatrix}$
#
# $
# \begin{align}
# C &= \begin{bmatrix}
#       (1)(-8) & (-1)(-6) & (1)(2)\\
#       (-1)(-18) & (1)(-11) & (-1)(-3)\\
#       (1)(-4) & (-1)(-8) & (1)(-4)
#       \end{bmatrix}\\
#    &= \begin{bmatrix}
#       -8 & 6 & 2\\
#       18 & -11 & 3\\
#       -4 & 8 & -4
#       \end{bmatrix}
# \end{align}
# $
#
# $
# \begin{align}
# C^T &= \boxed{\begin{bmatrix}
#        -8 & 18 & -4\\
#        6 & -11 & 8\\
#        2 & 3 & -4
#        \end{bmatrix}}
# \end{align}
# $
#
# $
# \begin{align}
# \Longrightarrow A^{-1} &= \frac{1}{20} \begin{bmatrix}
#                        -8 & 18 & -4\\
#                        6 & -11 & 8\\
#                        2 & 3 & -4
#                        \end{bmatrix}\\
#        &= \begin{bmatrix}
#           \frac{-8}{20} & \frac{18}{20} & \frac{-4}{20}\\
#           \frac{6}{20} & \frac{-11}{20} & \frac{8}{20}\\
#           \frac{2}{20} & \frac{3}{20} & \frac{-4}{20}
#           \end{bmatrix}\\
#        &= \boxed{\begin{bmatrix}
#           \frac{-2}{5} & \frac{9}{10} & \frac{-1}{5}\\
#           \frac{3}{10} & \frac{-11}{20} & \frac{2}{5}\\
#           \frac{1}{10} & \frac{3}{20} & \frac{-1}{5}
#           \end{bmatrix}}
# \end{align}
# $

# %% [markdown]
# 2) Solve for $x$ by evaluating $A^{-1}b$.
