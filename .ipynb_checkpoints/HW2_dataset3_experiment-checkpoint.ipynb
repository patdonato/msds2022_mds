# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plt.rcParams['figure.figsize'] = [15, 5]

# %%
import inspect
import itertools
import re
pd.set_option('max_colwidth', 400)

# %%
def linear(x, m1, b1):
    return m1*x + b1

def quadratic(x, a2, b2, c2):
    return (a2 * x * x) + (b2 * x) + c2

def quadraticn(x, a2n, b2n, c2n):
    return (-a2n * x * x) + (b2n * x) + c2n

def cubic(x, a3, b3, c3, d3):
    return (a3 * x * x * x) + (b3 * x * x) + (c3 * x) + d3

def sine(x, A4, f4, C4):
    return A4 * np.sin((2 * np.pi * f4 * x) + C4)

def sinec(x, A4c, f4c, C4c, D4c):
    return A4c * np.sin((2 * np.pi * f4c * x) + C4c) + D4c

def exponential(x, A5, b5):
    return A5 * np.exp(-b5 * x)

def powerlaw(x, A6, alpha6):
    return A6 * (np.power(x, alpha6))

def powerlawn(x, A6m, alpha6n):
    return A6m * (np.power(x, -alpha6n))

def logistic(x, A7, k7, x07):
    return A7/(1 + np.exp(-k7 * (x - x07)))

def gaussian(x, mean, stdev):
    return (1/np.sqrt(2 * np.pi * stdev**2)) * np.exp(-(x - mean)**2 / (2*stdev**2))

# %%
def calc_ssr(y, yhat):
    return sum((y - yhat)**2)

names = ['linear', 'quadratic', 'quadraticn', 'cubic', 'sine', 'sinec', 'exponential', 'logistic', 'powerlaw']
fns = [linear, quadratic, quadraticn, cubic,  sine, sinec, exponential, logistic, powerlaw]
fns_dict = dict(zip(names, fns))

names_comb = []
for L in range(0, len(names)+1):
    for subset in itertools.combinations(names, L):    
        names_comb.append(' o '.join(subset))
names_comb = names_comb[1:]
names_comb = [fn for fn in names_comb if len(re.findall('quadratic', fn)) <= 1]
names_comb = [fn for fn in names_comb if len(re.findall('sine', fn)) <= 1]
names_comb = [fn for fn in names_comb if len(re.findall(' o ', fn)) == 1]

for i in range(len(names_comb)):
    text2 = []
    all_args = []
    for fn in names_comb[i].split(' o '):
        args = inspect.getfullargspec(fns_dict[fn]).args[1:]
        all_args.append(args)
        text2.append(f"{fn}(x, {', '.join(args)})")
    text2 = text2[0].replace("(x",  "(" + text2[1])
    text1 = f"def my_{names_comb[i].replace(' o ', '_')}(x, {', '.join(list(itertools.chain(*all_args)))}):"
    exec(f"{text1}\n\treturn {text2}")
    print(f"Successfully created fn: {text1}\n\treturn {text2}")

fns_comb = []
for L in range(0, len(names)+1):
    for subset in itertools.combinations(names, L):    
        fns_comb.append('_'.join(subset))
fns_comb = fns_comb[1:]
fns_comb = ['my_' + fn for fn in fns_comb]
fns_comb = [fn for fn in fns_comb if len(re.findall('quadratic', fn)) <= 1]
fns_comb = [fn for fn in fns_comb if len(re.findall('sine', fn)) <= 1]
fns_comb = [fn for fn in fns_comb if len(re.findall('_', fn)) == 2]
fns_comb = [eval(fn) for fn in fns_comb]

def find_fn(x, y, ind, starting_param = 1):
    name_list = []
    popt_list = []
    ssr_list = []

    fns_comb_dict = dict(zip([names_comb[i] for i in ind], 
                             [fns_comb[i] for i in ind]))
    for name, fn in fns_comb_dict.items():
        n_args = len(inspect.getfullargspec(fn).args) - 1
        p0 = [starting_param]*n_args
        popt, pcov = curve_fit(fn, x, y, p0 = p0)
        yhat = fn(x, *popt) ## calculate yhat

        # Saving output
        name_list.append(name)
        popt_list.append(popt)
        ssr_list.append(calc_ssr(y, yhat))

    params_df = pd.DataFrame({'name': name_list,
                              'parameters': popt_list,
                              'ssr': ssr_list})
    params_df = params_df.sort_values('ssr')
    return params_df
# Out:
# Successfully created fn: def my_linear_quadratic(x, m1, b1, a2, b2, c2):
# 	return linear(quadratic(x, a2, b2, c2), m1, b1)
# Successfully created fn: def my_linear_quadraticn(x, m1, b1, a2n, b2n, c2n):
# 	return linear(quadraticn(x, a2n, b2n, c2n), m1, b1)
# Successfully created fn: def my_linear_cubic(x, m1, b1, a3, b3, c3, d3):
# 	return linear(cubic(x, a3, b3, c3, d3), m1, b1)
# Successfully created fn: def my_linear_sine(x, m1, b1, A4, f4, C4):
# 	return linear(sine(x, A4, f4, C4), m1, b1)
# Successfully created fn: def my_linear_sinec(x, m1, b1, A4c, f4c, C4c, D4c):
# 	return linear(sinec(x, A4c, f4c, C4c, D4c), m1, b1)
# Successfully created fn: def my_linear_exponential(x, m1, b1, A5, b5):
# 	return linear(exponential(x, A5, b5), m1, b1)
# Successfully created fn: def my_linear_logistic(x, m1, b1, A7, k7, x07):
# 	return linear(logistic(x, A7, k7, x07), m1, b1)
# Successfully created fn: def my_linear_powerlaw(x, m1, b1, A6, alpha6):
# 	return linear(powerlaw(x, A6, alpha6), m1, b1)
# Successfully created fn: def my_quadratic_cubic(x, a2, b2, c2, a3, b3, c3, d3):
# 	return quadratic(cubic(x, a3, b3, c3, d3), a2, b2, c2)
# Successfully created fn: def my_quadratic_sine(x, a2, b2, c2, A4, f4, C4):
# 	return quadratic(sine(x, A4, f4, C4), a2, b2, c2)
# Successfully created fn: def my_quadratic_sinec(x, a2, b2, c2, A4c, f4c, C4c, D4c):
# 	return quadratic(sinec(x, A4c, f4c, C4c, D4c), a2, b2, c2)
# Successfully created fn: def my_quadratic_exponential(x, a2, b2, c2, A5, b5):
# 	return quadratic(exponential(x, A5, b5), a2, b2, c2)
# Successfully created fn: def my_quadratic_logistic(x, a2, b2, c2, A7, k7, x07):
# 	return quadratic(logistic(x, A7, k7, x07), a2, b2, c2)
# Successfully created fn: def my_quadratic_powerlaw(x, a2, b2, c2, A6, alpha6):
# 	return quadratic(powerlaw(x, A6, alpha6), a2, b2, c2)
# Successfully created fn: def my_quadraticn_cubic(x, a2n, b2n, c2n, a3, b3, c3, d3):
# 	return quadraticn(cubic(x, a3, b3, c3, d3), a2n, b2n, c2n)
# Successfully created fn: def my_quadraticn_sine(x, a2n, b2n, c2n, A4, f4, C4):
# 	return quadraticn(sine(x, A4, f4, C4), a2n, b2n, c2n)
# Successfully created fn: def my_quadraticn_sinec(x, a2n, b2n, c2n, A4c, f4c, C4c, D4c):
# 	return quadraticn(sinec(x, A4c, f4c, C4c, D4c), a2n, b2n, c2n)
# Successfully created fn: def my_quadraticn_exponential(x, a2n, b2n, c2n, A5, b5):
# 	return quadraticn(exponential(x, A5, b5), a2n, b2n, c2n)
# Successfully created fn: def my_quadraticn_logistic(x, a2n, b2n, c2n, A7, k7, x07):
# 	return quadraticn(logistic(x, A7, k7, x07), a2n, b2n, c2n)
# Successfully created fn: def my_quadraticn_powerlaw(x, a2n, b2n, c2n, A6, alpha6):
# 	return quadraticn(powerlaw(x, A6, alpha6), a2n, b2n, c2n)
# Successfully created fn: def my_cubic_sine(x, a3, b3, c3, d3, A4, f4, C4):
# 	return cubic(sine(x, A4, f4, C4), a3, b3, c3, d3)
# Successfully created fn: def my_cubic_sinec(x, a3, b3, c3, d3, A4c, f4c, C4c, D4c):
# 	return cubic(sinec(x, A4c, f4c, C4c, D4c), a3, b3, c3, d3)
# Successfully created fn: def my_cubic_exponential(x, a3, b3, c3, d3, A5, b5):
# 	return cubic(exponential(x, A5, b5), a3, b3, c3, d3)
# Successfully created fn: def my_cubic_logistic(x, a3, b3, c3, d3, A7, k7, x07):
# 	return cubic(logistic(x, A7, k7, x07), a3, b3, c3, d3)
# Successfully created fn: def my_cubic_powerlaw(x, a3, b3, c3, d3, A6, alpha6):
# 	return cubic(powerlaw(x, A6, alpha6), a3, b3, c3, d3)
# Successfully created fn: def my_sine_exponential(x, A4, f4, C4, A5, b5):
# 	return sine(exponential(x, A5, b5), A4, f4, C4)
# Successfully created fn: def my_sine_logistic(x, A4, f4, C4, A7, k7, x07):
# 	return sine(logistic(x, A7, k7, x07), A4, f4, C4)
# Successfully created fn: def my_sine_powerlaw(x, A4, f4, C4, A6, alpha6):
# 	return sine(powerlaw(x, A6, alpha6), A4, f4, C4)
# Successfully created fn: def my_sinec_exponential(x, A4c, f4c, C4c, D4c, A5, b5):
# 	return sinec(exponential(x, A5, b5), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_sinec_logistic(x, A4c, f4c, C4c, D4c, A7, k7, x07):
# 	return sinec(logistic(x, A7, k7, x07), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_sinec_powerlaw(x, A4c, f4c, C4c, D4c, A6, alpha6):
# 	return sinec(powerlaw(x, A6, alpha6), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_exponential_logistic(x, A5, b5, A7, k7, x07):
# 	return exponential(logistic(x, A7, k7, x07), A5, b5)
# Successfully created fn: def my_exponential_powerlaw(x, A5, b5, A6, alpha6):
# 	return exponential(powerlaw(x, A6, alpha6), A5, b5)
# Successfully created fn: def my_logistic_powerlaw(x, A7, k7, x07, A6, alpha6):
# 	return logistic(powerlaw(x, A6, alpha6), A7, k7, x07)

# %%
df3 = pd.read_csv('~/Desktop/fit_data3.csv')

# %%
x3 = df3.x.to_numpy()
y3 = df3.y.to_numpy()

# %%
plt.plot(x3, y3, 'b-')

# %%
ind = list(range(0,7)) +\
list(range(8,13)) +\
list(range(15,19)) +\
list(range(20,24)) +\
list(range(25,27)) +\
list(range(28,30)) +\
list(range(31,32)) +\
list(range(33,33))

params_df = find_fn(x3, y3, ind = ind)
params_df.assign(parameters = [np.around(l,2) for l in params_df.parameters])
# Out:
# C:\Users\pdonato\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
#                         name  \
# 23          sinec o logistic
# 2             linear o cubic
# 7          quadratic o cubic
# 10   quadratic o exponential
# 18       cubic o exponential
# 5       linear o exponential
# 14  quadraticn o exponential
# 1        linear o quadraticn
# 0         linear o quadratic
# 22       sinec o exponential
# 17             cubic o sinec
# 24    exponential o logistic
# 16              cubic o sine
# 8           quadratic o sine
# 9          quadratic o sinec
# 3              linear o sine
# 4             linear o sinec
# 13        quadraticn o sinec
# 12         quadraticn o sine
# 15     quadraticn o logistic
# 19          cubic o logistic
# 11      quadratic o logistic
# 6          linear o logistic
# 21           sine o logistic
# 20        sine o exponential
#
#                                            parameters          ssr
# 23          [6.3, 1.29, -0.0, 3.06, 1.13, 0.61, 1.38]  3566.828859
# 2            [1.69, -947.0, 0.0, -0.0, -0.16, 562.92]  4050.417654
# 7   [0.31, -204.41, 31025.71, -0.0, 0.0, 0.0, 238.44]  4050.453515
# 10                      [0.0, -0.0, 5.43, 0.11, 0.89]  4084.015099
# 18              [-0.01, 64.67, 42.4, 5.4, -0.0, 0.99]  4086.539004
# 5                           [1.18, 5.39, -0.01, 0.56]  4129.004244
# 14                     [0.01, -66.59, 5.2, 0.0, 1.01]  4163.799150
# 1                  [1.25, -185.95, 0.0, 0.11, 153.15]  4214.150645
# 0                   [1.47, -64.56, -0.0, 0.09, 47.27]  4214.150648
# 22            [0.31, 734.14, 0.97, 5.0, -732.14, 1.0]  4308.658159
# 17    [-0.86, 0.68, 0.36, 4.72, 0.78, 1.0, 1.6, 0.27]  4311.553337
# 24                 [4.95, -0.21, -0.21, 36.76, -0.52]  4311.623527
# 16        [-1.49, 4.23, 0.61, 4.77, 0.19, 1.01, 1.54]  4311.938460
# 8               [7.71, -0.75, 4.77, 0.14, 1.01, -1.6]  4311.938547
# 9          [0.69, 0.34, 3.68, 0.06, 1.01, 1.47, 1.08]  4312.051204
# 3                    [-0.09, 4.84, -1.36, 1.01, 1.47]  4312.052435
# 4                 [0.8, 3.35, 0.14, 1.01, 1.46, 1.86]  4312.052463
# 13           [1.04, 2.25, 3.7, 0.25, 1.0, 1.49, 0.87]  4312.058344
# 12             [10.34, -1.37, 4.88, -0.08, 1.0, 1.49]  4312.058404
# 15    [-192.22, -108.67, 4.84, 82.22, -43.87, -40.03]  4312.724746
# 19     [-6.47, -35.7, 50.48, 4.84, -0.16, 6.64, 27.1]  4312.724746
# 11     [-227.59, 279.51, 4.84, -15.83, 23.07, 142.78]  4312.724746
# 6                       [0.0, 4.84, 0.0, -6.59, 2.25]  4312.724747
# 21           [6.62, -10.11, -5.49, 12.16, 1.46, -0.9]  4352.935855
# 20                      [4.84, 0.43, 1.84, 1.74, 1.0]  5164.222918

# %%
names = ['linear', 'quadratic', 'quadraticn', 'cubic', 'sine', 'sinec', 'exponential', 'logistic', 'powerlaw']
fns = [linear, quadratic, quadraticn, cubic,  sine, sinec, exponential, logistic, powerlaw]
fns_dict = dict(zip(names, fns))

names_comb = []
for L in range(0, len(names)+1):
    for subset in itertools.combinations(names, L):    
        names_comb.append(' o '.join(subset))
names_comb = names_comb[1:]
names_comb = [fn for fn in names_comb if len(re.findall('quadratic', fn)) <= 1]
names_comb = [fn for fn in names_comb if len(re.findall('sine', fn)) <= 1]
names_comb = [fn for fn in names_comb if len(re.findall(' o ', fn)) == 1]

for i in range(len(names_comb)):
    text2 = []
    all_args = []
    for fn in names_comb[i].split(' o '):
        args = inspect.getfullargspec(fns_dict[fn]).args[1:]
        all_args.append(args)
        text2.append(f"{fn}(x, {', '.join(args)})")
    text2 = text2[1].replace("(x",  "(" + text2[0])
    text1 = f"def my_{names_comb[i].replace(' o ', '_')}(x, {', '.join(list(itertools.chain(*all_args)))}):"
    exec(f"{text1}\n\treturn {text2}")
    print(f"Successfully created fn: {text1}\n\treturn {text2}")

fns_comb = []
for L in range(0, len(names)+1):
    for subset in itertools.combinations(names, L):    
        fns_comb.append('_'.join(subset))
fns_comb = fns_comb[1:]
fns_comb = ['my_' + fn for fn in fns_comb]
fns_comb = [fn for fn in fns_comb if len(re.findall('quadratic', fn)) <= 1]
fns_comb = [fn for fn in fns_comb if len(re.findall('sine', fn)) <= 1]
fns_comb = [fn for fn in fns_comb if len(re.findall('_', fn)) == 2]
fns_comb = [eval(fn) for fn in fns_comb]

def find_fn_switch(x, y, ind, starting_param = 1):
    name_list = []
    popt_list = []
    ssr_list = []

    fns_comb_dict = dict(zip([names_comb[i] for i in ind], 
                             [fns_comb[i] for i in ind]))
    for name, fn in fns_comb_dict.items():
        n_args = len(inspect.getfullargspec(fn).args) - 1
        p0 = [starting_param]*n_args
        popt, pcov = curve_fit(fn, x, y, p0 = p0)
        yhat = fn(x, *popt) ## calculate yhat

        # Saving output
        name_list.append(name)
        popt_list.append(popt)
        ssr_list.append(calc_ssr(y, yhat))

    params_df = pd.DataFrame({'name': name_list,
                              'parameters': popt_list,
                              'ssr': ssr_list})
    params_df = params_df.sort_values('ssr')
    return params_df
# Out:
# Successfully created fn: def my_linear_quadratic(x, m1, b1, a2, b2, c2):
# 	return quadratic(linear(x, m1, b1), a2, b2, c2)
# Successfully created fn: def my_linear_quadraticn(x, m1, b1, a2n, b2n, c2n):
# 	return quadraticn(linear(x, m1, b1), a2n, b2n, c2n)
# Successfully created fn: def my_linear_cubic(x, m1, b1, a3, b3, c3, d3):
# 	return cubic(linear(x, m1, b1), a3, b3, c3, d3)
# Successfully created fn: def my_linear_sine(x, m1, b1, A4, f4, C4):
# 	return sine(linear(x, m1, b1), A4, f4, C4)
# Successfully created fn: def my_linear_sinec(x, m1, b1, A4c, f4c, C4c, D4c):
# 	return sinec(linear(x, m1, b1), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_linear_exponential(x, m1, b1, A5, b5):
# 	return exponential(linear(x, m1, b1), A5, b5)
# Successfully created fn: def my_linear_logistic(x, m1, b1, A7, k7, x07):
# 	return logistic(linear(x, m1, b1), A7, k7, x07)
# Successfully created fn: def my_linear_powerlaw(x, m1, b1, A6, alpha6):
# 	return powerlaw(linear(x, m1, b1), A6, alpha6)
# Successfully created fn: def my_quadratic_cubic(x, a2, b2, c2, a3, b3, c3, d3):
# 	return cubic(quadratic(x, a2, b2, c2), a3, b3, c3, d3)
# Successfully created fn: def my_quadratic_sine(x, a2, b2, c2, A4, f4, C4):
# 	return sine(quadratic(x, a2, b2, c2), A4, f4, C4)
# Successfully created fn: def my_quadratic_sinec(x, a2, b2, c2, A4c, f4c, C4c, D4c):
# 	return sinec(quadratic(x, a2, b2, c2), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_quadratic_exponential(x, a2, b2, c2, A5, b5):
# 	return exponential(quadratic(x, a2, b2, c2), A5, b5)
# Successfully created fn: def my_quadratic_logistic(x, a2, b2, c2, A7, k7, x07):
# 	return logistic(quadratic(x, a2, b2, c2), A7, k7, x07)
# Successfully created fn: def my_quadratic_powerlaw(x, a2, b2, c2, A6, alpha6):
# 	return powerlaw(quadratic(x, a2, b2, c2), A6, alpha6)
# Successfully created fn: def my_quadraticn_cubic(x, a2n, b2n, c2n, a3, b3, c3, d3):
# 	return cubic(quadraticn(x, a2n, b2n, c2n), a3, b3, c3, d3)
# Successfully created fn: def my_quadraticn_sine(x, a2n, b2n, c2n, A4, f4, C4):
# 	return sine(quadraticn(x, a2n, b2n, c2n), A4, f4, C4)
# Successfully created fn: def my_quadraticn_sinec(x, a2n, b2n, c2n, A4c, f4c, C4c, D4c):
# 	return sinec(quadraticn(x, a2n, b2n, c2n), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_quadraticn_exponential(x, a2n, b2n, c2n, A5, b5):
# 	return exponential(quadraticn(x, a2n, b2n, c2n), A5, b5)
# Successfully created fn: def my_quadraticn_logistic(x, a2n, b2n, c2n, A7, k7, x07):
# 	return logistic(quadraticn(x, a2n, b2n, c2n), A7, k7, x07)
# Successfully created fn: def my_quadraticn_powerlaw(x, a2n, b2n, c2n, A6, alpha6):
# 	return powerlaw(quadraticn(x, a2n, b2n, c2n), A6, alpha6)
# Successfully created fn: def my_cubic_sine(x, a3, b3, c3, d3, A4, f4, C4):
# 	return sine(cubic(x, a3, b3, c3, d3), A4, f4, C4)
# Successfully created fn: def my_cubic_sinec(x, a3, b3, c3, d3, A4c, f4c, C4c, D4c):
# 	return sinec(cubic(x, a3, b3, c3, d3), A4c, f4c, C4c, D4c)
# Successfully created fn: def my_cubic_exponential(x, a3, b3, c3, d3, A5, b5):
# 	return exponential(cubic(x, a3, b3, c3, d3), A5, b5)
# Successfully created fn: def my_cubic_logistic(x, a3, b3, c3, d3, A7, k7, x07):
# 	return logistic(cubic(x, a3, b3, c3, d3), A7, k7, x07)
# Successfully created fn: def my_cubic_powerlaw(x, a3, b3, c3, d3, A6, alpha6):
# 	return powerlaw(cubic(x, a3, b3, c3, d3), A6, alpha6)
# Successfully created fn: def my_sine_exponential(x, A4, f4, C4, A5, b5):
# 	return exponential(sine(x, A4, f4, C4), A5, b5)
# Successfully created fn: def my_sine_logistic(x, A4, f4, C4, A7, k7, x07):
# 	return logistic(sine(x, A4, f4, C4), A7, k7, x07)
# Successfully created fn: def my_sine_powerlaw(x, A4, f4, C4, A6, alpha6):
# 	return powerlaw(sine(x, A4, f4, C4), A6, alpha6)
# Successfully created fn: def my_sinec_exponential(x, A4c, f4c, C4c, D4c, A5, b5):
# 	return exponential(sinec(x, A4c, f4c, C4c, D4c), A5, b5)
# Successfully created fn: def my_sinec_logistic(x, A4c, f4c, C4c, D4c, A7, k7, x07):
# 	return logistic(sinec(x, A4c, f4c, C4c, D4c), A7, k7, x07)
# Successfully created fn: def my_sinec_powerlaw(x, A4c, f4c, C4c, D4c, A6, alpha6):
# 	return powerlaw(sinec(x, A4c, f4c, C4c, D4c), A6, alpha6)
# Successfully created fn: def my_exponential_logistic(x, A5, b5, A7, k7, x07):
# 	return logistic(exponential(x, A5, b5), A7, k7, x07)
# Successfully created fn: def my_exponential_powerlaw(x, A5, b5, A6, alpha6):
# 	return powerlaw(exponential(x, A5, b5), A6, alpha6)
# Successfully created fn: def my_logistic_powerlaw(x, A7, k7, x07, A6, alpha6):
# 	return powerlaw(logistic(x, A7, k7, x07), A6, alpha6)

# %%
ind = list(range(1,7)) +\
list(range(9,13)) +\
list(range(14,19)) +\
list(range(20,22)) +\
list(range(23,24)) +\
list(range(25,27)) +\
list(range(28,29)) +\
list(range(30,32)) +\
list(range(33,33))

params_df = find_fn_switch(x3, y3, ind = ind)
params_df.assign(parameters = [np.around(l,2) for l in params_df.parameters])
# Out:
# C:\Users\pdonato\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in power
#                         name  \
# 7          quadratic o sinec
# 9       quadratic o logistic
# 16             cubic o sinec
# 1             linear o cubic
# 12        quadraticn o sinec
# 10        quadraticn o cubic
# 0        linear o quadraticn
# 8    quadratic o exponential
# 3             linear o sinec
# 18        sine o exponential
# 20       sinec o exponential
# 19           sine o logistic
# 21          sinec o powerlaw
# 17          cubic o logistic
# 22    exponential o logistic
# 14     quadraticn o logistic
# 5          linear o logistic
# 15              cubic o sine
# 11         quadraticn o sine
# 6           quadratic o sine
# 13  quadraticn o exponential
# 2              linear o sine
# 4       linear o exponential
#
#                                                       parameters          ssr
# 7         [100.94, 100.92, 322.33, -2.49, -98.93, -1707.2, 4.89]  3948.838806
# 9                        [10.9, -34.21, 12.58, 5.65, 0.2, 24.25]  3967.445382
# 16  [2.06, 2.01, 3.99, 37505.91, -2.62, -0.19, -234031.63, 4.51]  4011.676207
# 1                         [0.72, -2.22, 0.01, 0.07, -0.23, 4.26]  4050.417654
# 12         [85.44, 85.46, -3581.5, -2.14, -83.44, 23085.5, 4.85]  4090.280215
# 10           [-0.05, 0.41, -38.72, -0.01, -0.6, -17.12, -148.91]  4145.560225
# 0                              [0.04, 4.81, 1.85, 21.34, -54.78]  4214.150645
# 8                                [0.0, 5.06, -9.46, 4.99, -0.01]  4217.574767
# 3                  [-13.46, 738.41, 0.21, 15.46, -4722.93, 4.84]  4310.625001
# 18                              [-0.14, 0.96, 1.49, 4.84, -0.23]  4311.600915
# 20                         [0.9, 1.01, -1.67, -0.66, 4.76, 0.03]  4312.051890
# 19                         [0.44, 1.01, 1.47, 6.24, 0.25, -5.07]  4312.053741
# 21                         [-0.09, 0.92, -1.7, 2.88, 2.38, 0.67]  4312.199177
# 17         [699.03, 784.4, 833.92, 274.18, 4.84, -814.0, 275.58]  5484.053343
# 22                        [321.18, 66.15, 4.84, -358.37, 333.51]  5485.877338
# 14                        [0.75, -18.56, 1.0, 4.84, -31.08, 1.0]  5485.877338
# 5                          [110.45, -81.36, 4.43, -34.18, 59.98]  5578.838317
# 15     [13.92, 13.93, 13.92, 43411.21, 3.77, -11.92, -272676.51]  5961.605331
# 11               [100.9, 100.89, 376.29, -3.76, -98.9, -2093.07]  5970.126008
# 6                          [3.39, 3.34, 1.02, 2.68, -1.06, 3.38]  6336.480669
# 13                                  [1.0, -0.0, 22.38, 0.0, 1.0]  6655.196921
# 2                       [-32.41, 730.04, -0.02, 34.36, -4785.34]  6657.179428
# 4                              [24.01, -320.02, -344.03, -22.01]  6657.206291
